# %%
import pandas as pd
import matplotlib.pyplot as pt
import numpy as np 
import seaborn as sb
import tensorflow as tf
import keras_preprocessing

# %%
df1=pd.read_csv('./Nowcast_R_2022-02-20.csv',index_col='Datum',parse_dates=True)

# %%
df1.head(800)
# Out:
#             PS_COVID_Faelle  UG_PI_COVID_Faelle  OG_PI_COVID_Faelle  \
# Datum
# 2020-03-02              304                 292                 319
# 2020-03-03              321                 304                 337
# 2020-03-04              448                 430                 467
# 2020-03-05              503                 485                 525
# 2020-03-06              757                 732                 783
# ...                     ...                 ...                 ...
# 2022-02-12           154702              135245              179943
# 2022-02-13           163441              138246              192960
# 2022-02-14           178129              139047              210209
# 2022-02-15           182536              136079              224731
# 2022-02-16           174732              117709              226614
#
#             PS_COVID_Faelle_ma4  UG_PI_COVID_Faelle_ma4  \
# Datum
# 2020-03-02                  225                     213
# 2020-03-03                  261                     248
# 2020-03-04                  326                     311
# 2020-03-05                  394                     378
# 2020-03-06                  507                     488
# ...                         ...                     ...
# 2022-02-12               157628                  145616
# 2022-02-13               155834                  139878
# 2022-02-14               161325                  137986
# 2022-02-15               169702                  137154
# 2022-02-16               174710                  132770
#
#             OG_PI_COVID_Faelle_ma4  PS_7_Tage_R_Wert  UG_PI_7_Tage_R_Wert  \
# Datum
# 2020-03-02                     238               NaN                  NaN
# 2020-03-03                     276               NaN                  NaN
# 2020-03-04                     342               NaN                  NaN
# 2020-03-05                     412               NaN                  NaN
# 2020-03-06                     528              2.34                 2.28
# ...                            ...               ...                  ...
# 2022-02-12                  171179              0.95                 0.92
# 2022-02-13                  174590              0.95                 0.91
# 2022-02-14                  185883              0.96                 0.90
# 2022-02-15                  201961              0.97                 0.90
# 2022-02-16                  213628               NaN                  NaN
#
#             OG_PI_7_Tage_R_Wert
# Datum
# 2020-03-02                  NaN
# 2020-03-03                  NaN
# 2020-03-04                  NaN
# 2020-03-05                  NaN
# 2020-03-06                 2.39
# ...                         ...
# 2022-02-12                 0.98
# 2022-02-13                 0.99
# 2022-02-14                 1.02
# 2022-02-15                 1.05
# 2022-02-16                  NaN
#
# [717 rows x 9 columns]

# %%
df1
# Out:
#             PS_COVID_Faelle  UG_PI_COVID_Faelle  OG_PI_COVID_Faelle  \
# Datum
# 2020-03-02              304                 292                 319
# 2020-03-03              321                 304                 337
# 2020-03-04              448                 430                 467
# 2020-03-05              503                 485                 525
# 2020-03-06              757                 732                 783
# ...                     ...                 ...                 ...
# 2022-02-12           154702              135245              179943
# 2022-02-13           163441              138246              192960
# 2022-02-14           178129              139047              210209
# 2022-02-15           182536              136079              224731
# 2022-02-16           174732              117709              226614
#
#             PS_COVID_Faelle_ma4  UG_PI_COVID_Faelle_ma4  \
# Datum
# 2020-03-02                  225                     213
# 2020-03-03                  261                     248
# 2020-03-04                  326                     311
# 2020-03-05                  394                     378
# 2020-03-06                  507                     488
# ...                         ...                     ...
# 2022-02-12               157628                  145616
# 2022-02-13               155834                  139878
# 2022-02-14               161325                  137986
# 2022-02-15               169702                  137154
# 2022-02-16               174710                  132770
#
#             OG_PI_COVID_Faelle_ma4  PS_7_Tage_R_Wert  UG_PI_7_Tage_R_Wert  \
# Datum
# 2020-03-02                     238               NaN                  NaN
# 2020-03-03                     276               NaN                  NaN
# 2020-03-04                     342               NaN                  NaN
# 2020-03-05                     412               NaN                  NaN
# 2020-03-06                     528              2.34                 2.28
# ...                            ...               ...                  ...
# 2022-02-12                  171179              0.95                 0.92
# 2022-02-13                  174590              0.95                 0.91
# 2022-02-14                  185883              0.96                 0.90
# 2022-02-15                  201961              0.97                 0.90
# 2022-02-16                  213628               NaN                  NaN
#
#             OG_PI_7_Tage_R_Wert
# Datum
# 2020-03-02                  NaN
# 2020-03-03                  NaN
# 2020-03-04                  NaN
# 2020-03-05                  NaN
# 2020-03-06                 2.39
# ...                         ...
# 2022-02-12                 0.98
# 2022-02-13                 0.99
# 2022-02-14                 1.02
# 2022-02-15                 1.05
# 2022-02-16                  NaN
#
# [717 rows x 9 columns]

# %%
df1.mean()
# Out:
# PS_COVID_Faelle           18740.002789
# UG_PI_COVID_Faelle        18211.967922
# OG_PI_COVID_Faelle        19261.124128
# PS_COVID_Faelle_ma4       18368.283124
# UG_PI_COVID_Faelle_ma4    17945.687587
# OG_PI_COVID_Faelle_ma4    18794.358438
# PS_7_Tage_R_Wert              1.058216
# UG_PI_7_Tage_R_Wert           1.049326
# OG_PI_7_Tage_R_Wert           1.067163
# dtype: float64

# %%
#die Df1 dropen nur mit 3 oder 4 werten arbeiten
df1=df1.drop('UG_PI_COVID_Faelle',axis=1)

# %%
df1.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Datum'>

# %% [markdown]
# # Modell bearbeiten denk an die Layer keras etc.

# %%
df1.corr()
# Out:
#                         PS_COVID_Faelle  OG_PI_COVID_Faelle  \
# PS_COVID_Faelle                1.000000            0.997310
# OG_PI_COVID_Faelle             0.997310            1.000000
# PS_COVID_Faelle_ma4            0.994733            0.992459
# UG_PI_COVID_Faelle_ma4         0.993008            0.986374
# OG_PI_COVID_Faelle_ma4         0.993176            0.994893
# PS_7_Tage_R_Wert               0.052672            0.048146
# UG_PI_7_Tage_R_Wert            0.056333            0.050752
# OG_PI_7_Tage_R_Wert            0.051306            0.047812
#
#                         PS_COVID_Faelle_ma4  UG_PI_COVID_Faelle_ma4  \
# PS_COVID_Faelle                    0.994733                0.993008
# OG_PI_COVID_Faelle                 0.992459                0.986374
# PS_COVID_Faelle_ma4                1.000000                0.998152
# UG_PI_COVID_Faelle_ma4             0.998152                1.000000
# OG_PI_COVID_Faelle_ma4             0.998489                0.993317
# PS_7_Tage_R_Wert                   0.037831                0.040907
# UG_PI_7_Tage_R_Wert                0.041388                0.045278
# OG_PI_7_Tage_R_Wert                0.036465                0.038743
#
#                         OG_PI_COVID_Faelle_ma4  PS_7_Tage_R_Wert  \
# PS_COVID_Faelle                       0.993176          0.052672
# OG_PI_COVID_Faelle                    0.994893          0.048146
# PS_COVID_Faelle_ma4                   0.998489          0.037831
# UG_PI_COVID_Faelle_ma4                0.993317          0.040907
# OG_PI_COVID_Faelle_ma4                1.000000          0.034771
# PS_7_Tage_R_Wert                      0.034771          1.000000
# UG_PI_7_Tage_R_Wert                   0.037532          0.999341
# OG_PI_7_Tage_R_Wert                   0.034179          0.999415
#
#                         UG_PI_7_Tage_R_Wert  OG_PI_7_Tage_R_Wert
# PS_COVID_Faelle                    0.056333             0.051306
# OG_PI_COVID_Faelle                 0.050752             0.047812
# PS_COVID_Faelle_ma4                0.041388             0.036465
# UG_PI_COVID_Faelle_ma4             0.045278             0.038743
# OG_PI_COVID_Faelle_ma4             0.037532             0.034179
# PS_7_Tage_R_Wert                   0.999341             0.999415
# UG_PI_7_Tage_R_Wert                1.000000             0.998019
# OG_PI_7_Tage_R_Wert                0.998019             1.000000

# %%
sb.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
X = df1.drop('PS_COVID_Faelle',axis=1).values
y = df1['OG_PI_COVID_Faelle'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.8,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 12
generator = TimeseriesGenerator(X_train,X_train, length=length, batch_size=1)

# %%
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [4.04968246e-04 6.01697310e-04 6.03742133e-04 5.99050735e-04
#  1.16279070e-01 1.12149533e-01 1.19815668e-01 9.21755371e-02
#  9.89975200e-02 1.00333394e-01 9.75787086e-02 1.58139535e-01
#  1.63551402e-01 1.56682028e-01 7.75013936e-02 8.56346075e-02
#  8.65648676e-02 8.45634354e-02 1.34883721e-01 1.40186916e-01
#  1.29032258e-01 2.17729986e-03 2.72595042e-03 2.73019672e-03
#  2.72388881e-03 7.44186047e-02 7.47663551e-02 7.83410138e-02
#  1.66275197e-03 1.62719881e-03 1.63491232e-03 1.60770881e-03
#  1.30232558e-01 1.26168224e-01 1.29032258e-01 1.34354171e-03
#  1.05689440e-03 1.05254159e-03 1.05985899e-03 1.02325581e-01
#  9.81308411e-02 1.05990783e-01 3.90675249e-04 2.72071827e-04
#  2.83171089e-04 2.56004588e-04 1.48837209e-01 1.40186916e-01
#  1.52073733e-01 1.87238259e-03 2.18180677e-03 2.18522595e-03
#  2.18627918e-03 9.30232558e-02 9.34579439e-02 9.21658986e-02
#  3.33884408e-02 3.96492366e-02 4.00606948e-02 3.91687019e-02
#  9.76744186e-02 1.02803738e-01 9.67741935e-02 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.06976744e-01
#  1.02803738e-01 1.15207373e-01 2.23256612e-02 2.17238890e-02
#  2.18736309e-02 2.15453461e-02 3.20930233e-01 3.22429907e-01
#  3.22580645e-01 9.35262253e-01 1.00000000e+00 1.00000000e+00
#  1.00000000e+00 1.76744186e-01 1.77570093e-01 1.75115207e-01]
# Predict this y:
#  [[0.07812076 0.08671766 0.08785249 0.08559769 0.1255814  0.12616822
#   0.11981567]]

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten,Activation,Dropout,LSTM
from tensorflow.keras.optimizers import Adam

# %%
#bitte 3 werte Droppen
n_features = 2

# %%
length=12

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 100)               43200
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 43,301
# Trainable params: 43,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
validation_generator = TimeseriesGenerator(X_test,X_test, length=length, batch_size=1)

# %%
model.fit_generator(generator,epochs=20,
                    validation_data=validation_generator,
                   callbacks=[early_stop])
# Out:
# Epoch 1/20
#  10/131 [=>............................] - ETA: 0s - loss: nan
# C:\Users\Mohamed Computer\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 131/131 [==============================] - 2s 13ms/step - loss: nan - val_loss: nan
# Epoch 2/20
# 131/131 [==============================] - 2s 13ms/step - loss: nan - val_loss: nan

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
X_train.shape
# Out:
# (143, 7)

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
# model=Sequential()
# model.add(Dense(9,activation='relu'))
# model.add(Dense(9,activation='relu'))
# model.add(Dense(9,activation='relu'))
# model.add(Dense(9,activation='relu'))
# model.add(Dense(1))

# #model compile


# model.compile(optimizer='adam',loss='mse')

model = Sequential()
model.add(Dense(units=50,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# model.fit(x=X_train,y=y_train,
#           validation_data=(X_test,y_test,
#           batch_size=128,epochs=400)

model.fit(x=X_train, 
          y=y_train, 
          epochs=400,
          validation_data=(X_test, y_test), verbose=1
          )
# Out:
# Epoch 1/400
# 5/5 [==============================] - 1s 77ms/step - loss: nan - val_loss: nan
# Epoch 2/400
# 5/5 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 3/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 4/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 5/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 6/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 7/400
# 5/5 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 8/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 9/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 10/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 11/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 12/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 13/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 14/400
# 5/5 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 15/400
# 5/5 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 16/400
# 5/5 [==============================] - 0s 20ms/step - loss: nan - val_loss: nan
# Epoch 17/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 18/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 19/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 20/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 21/400
# 5/5 [==============================] - 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 22/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 23/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 24/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 25/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 26/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 27/400
# 5/5 [==============================] - 0s 21ms/step - loss: nan - val_loss: nan
# Epoch 28/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 29/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 30/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 31/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 32/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 33/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 34/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 35/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 36/400
# 5/5 [==============================] - 0s 16ms/step - loss: nan - val_loss: nan
# Epoch 37/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 38/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 39/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 40/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 41/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 42/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 43/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 44/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 45/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 46/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 47/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 48/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 49/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 50/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 51/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 52/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 53/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 54/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 55/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 56/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 57/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 58/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 59/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 60/400
# 5/5 [==============================] - 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 61/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 62/400
# 5/5 [==============================] - 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 63/400
# 5/5 [==============================] - 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 64/400
# 1/5 [=====>........................] - ETA: 0s - loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-260a02b5d67f> in <module>
#       3 #           batch_size=128,epochs=400)
#       4
# ----> 5 model.fit(x=X_train,
#       6           y=y_train,
#       7           epochs=400,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1129                 model=self,
#    1130                 steps_per_execution=self._steps_per_execution)
# -> 1131           val_logs = self.evaluate(
#    1132               x=val_x,
#    1133               y=val_y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1381       self._test_counter.assign(0)
#    1382       callbacks.on_test_begin()
# -> 1383       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1384         self.reset_metrics()
#    1385         with data_handler.catch_stop_iteration():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1131     """Yields `(epoch, tf.data.Iterator)`."""
#    1132     with self._truncate_execution_to_epoch():
# -> 1133       data_iterator = iter(self._dataset)
#    1134       for epoch in range(self._initial_epoch, self._epochs):
#    1135         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     703               output_types=self._flat_output_types,
#     704               output_shapes=self._flat_output_shapes))
# --> 705       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     706       # Delete the resource when this object is deleted
#     707       self._resource_deleter = IteratorResourceDeleter(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    2968   if tld.is_eager:
#    2969     try:
# -> 2970       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2971         _ctx, "MakeIterator", name, dataset, iterator)
#    2972       return _result
#
# KeyboardInterrupt:

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
losses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
first_eval_batch = X_train[-length:]

# %%
first_eval_batch = first_eval_batch.reshape((1,-length, n_features))

# %%
len(df1)- 6
# Out:
# 711

# %%
test_size = 24

# %%
test_ind = len(df1)- test_size

# %%
model.predict(first_eval_batch)
# Out:
# array([[0.08884559]], dtype=float32)

# %%
test = df1.iloc[test_ind:]

# %%
X_test[0]
# Out:
# array([0.0191812])

# %%
test_predictions = []

first_eval_batch = X_train[-length:]
current_batch = first_eval_batch.reshape((1,-length,n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred)
    
    # update batch to now include prediction and drop first value
#     current_batch = np.append(current_batch[:,-1:,:],[[current_pred]],axis=1)
#     current_batch = np.append(current_batch[:0,:1],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test_predictions = []

first_eval_batch = X_train[-length:]
current_batch = first_eval_batch.reshape((1, -length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
#     current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
df1.plot(figsize=(10,10))
# Out:
# <img src="data:image/png;base64,..." width="1089.9166666666667">
# <AxesSubplot:xlabel='Datum'>

# %%
# %matplotlib notebook

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df1)

# %%
length = 12 # Length of the output sequences (in number of timesteps)
n_features=2
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=2)

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate=0.0001)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))

model.compile(optimizer=opt, loss='mse')


# fit model
model.fit_generator(generator,epochs=10)
# Out:
# C:\Users\Mohamed Computer\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 353/353 [==============================] - 4s 7ms/step - loss: 0.0302
# Epoch 2/10
# 353/353 [==============================] - 2s 7ms/step - loss: 0.0098
# Epoch 3/10
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0012
# Epoch 4/10
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0012
# Epoch 5/10
# 353/353 [==============================] - 2s 6ms/step - loss: 9.1670e-04
# Epoch 6/10
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4573e-04
# Epoch 7/10
# 353/353 [==============================] - 2s 6ms/step - loss: 7.3982e-04
# Epoch 8/10
# 353/353 [==============================] - 2s 6ms/step - loss: 6.3140e-04
# Epoch 9/10
# 353/353 [==============================] - 2s 6ms/step - loss: 7.4688e-04
# Epoch 10/10
# 353/353 [==============================] - 2s 6ms/step - loss: 6.1822e-04

# %%
forecast = []
# Replace periods with whatever forecast length you want
periods = 3

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[-1]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
#     current_batch = np.append(current_batch[:,:1,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
df1
# Out:
#             PS_COVID_Faelle  OG_PI_COVID_Faelle
# Datum
# 2020-03-02              304                 319
# 2020-03-03              321                 337
# 2020-03-04              448                 467
# 2020-03-05              503                 525
# 2020-03-06              757                 783
# ...                     ...                 ...
# 2022-02-12           154702              179943
# 2022-02-13           163441              192960
# 2022-02-14           178129              210209
# 2022-02-15           182536              224731
# 2022-02-16           174732              226614
#
# [717 rows x 2 columns]

# %%
test.max()
# Out:
# PS_COVID_Faelle           208598
# UG_PI_COVID_Faelle        204564
# OG_PI_COVID_Faelle        226614
# PS_COVID_Faelle_ma4       192494
# UG_PI_COVID_Faelle_ma4    187882
# OG_PI_COVID_Faelle_ma4    213628
# dtype: int64

# %%
test
# Out:
#             PS_COVID_Faelle  UG_PI_COVID_Faelle  OG_PI_COVID_Faelle  \
# Datum
# 2022-01-24           183906              181382              186179
# 2022-01-25           183822              181497              186452
# 2022-01-26           167505              165825              169338
# 2022-01-27           154176              151562              156535
# 2022-01-28           153441              150576              155803
# 2022-01-29           158868              156613              161768
# 2022-01-30           171030              167575              174450
# 2022-01-31           194798              191448              198778
# 2022-02-01           208598              204564              212758
# 2022-02-02           191353              186256              196621
# 2022-02-03           175227              169260              180499
# 2022-02-04           171647              166653              177994
# 2022-02-05           165964              159293              172254
# 2022-02-06           174151              166070              180554
# 2022-02-07           195160              186755              205160
# 2022-02-08           190953              181270              200019
# 2022-02-09           170616              161196              179316
# 2022-02-10           156164              146618              165035
# 2022-02-11           149029              139404              160421
# 2022-02-12           154702              135245              179943
# 2022-02-13           163441              138246              192960
# 2022-02-14           178129              139047              210209
# 2022-02-15           182536              136079              224731
# 2022-02-16           174732              117709              226614
#
#             PS_COVID_Faelle_ma4  UG_PI_COVID_Faelle_ma4  \
# Datum
# 2022-01-24               154535                  152643
# 2022-01-25               165788                  163713
# 2022-01-26               172333                  170207
# 2022-01-27               172352                  170067
# 2022-01-28               164736                  162365
# 2022-01-29               158498                  156144
# 2022-01-30               159379                  156581
# 2022-01-31               169534                  166553
# 2022-02-01               183324                  180050
# 2022-02-02               191445                  187461
# 2022-02-03               192494                  187882
# 2022-02-04               186706                  181683
# 2022-02-05               176048                  170365
# 2022-02-06               171747                  165319
# 2022-02-07               176731                  169693
# 2022-02-08               181557                  173347
# 2022-02-09               182720                  173823
# 2022-02-10               178223                  168960
# 2022-02-11               166691                  157122
# 2022-02-12               157628                  145616
# 2022-02-13               155834                  139878
# 2022-02-14               161325                  137986
# 2022-02-15               169702                  137154
# 2022-02-16               174710                  132770
#
#             OG_PI_COVID_Faelle_ma4
# Datum
# 2022-01-24                  156405
# 2022-01-25                  167882
# 2022-01-26                  174513
# 2022-01-27                  174626
# 2022-01-28                  167032
# 2022-01-29                  160861
# 2022-01-30                  162139
# 2022-01-31                  172700
# 2022-02-01                  186939
# 2022-02-02                  195652
# 2022-02-03                  197164
# 2022-02-04                  191968
# 2022-02-05                  181842
# 2022-02-06                  177825
# 2022-02-07                  183991
# 2022-02-08                  189497
# 2022-02-09                  191262
# 2022-02-10                  187383
# 2022-02-11                  176198
# 2022-02-12                  171179
# 2022-02-13                  174590
# 2022-02-14                  185883
# 2022-02-15                  201961
# 2022-02-16                  213628

# %%
forecast_index = pd.date_range(start='2022-01-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df.head(300)
# Out:
#                  Forecast
# 2022-01-01  178451.323126
# 2022-02-01  178451.323126
# 2022-03-01  178451.323126

# %%
df1.plot()
forecast_df.plot()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <AxesSubplot:>

# %%
ax = df1.plot()
forecast_df.plot(ax=ax)
pt.xlim('2020-01-01','2022-12-01')
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (18262.0, 19327.0)

# %%
import pandas as pd
import matplotlib.pyplot
import numpy as np 
import seaborn as sb
import tensorflow as tf

# %%
df2=pd.read_csv('./Nowcast_R_2022-02-20.csv',index_col='Datum',parse_dates=True)

# %%
df2.head(200).transpose()
# Out:
# Datum                   2020-03-02  2020-03-03  2020-03-04  2020-03-05  \
# PS_COVID_Faelle              304.0       321.0       448.0       503.0
# UG_PI_COVID_Faelle           292.0       304.0       430.0       485.0
# OG_PI_COVID_Faelle           319.0       337.0       467.0       525.0
# PS_COVID_Faelle_ma4          225.0       261.0       326.0       394.0
# UG_PI_COVID_Faelle_ma4       213.0       248.0       311.0       378.0
# OG_PI_COVID_Faelle_ma4       238.0       276.0       342.0       412.0
# PS_7_Tage_R_Wert               NaN         NaN         NaN         NaN
# UG_PI_7_Tage_R_Wert            NaN         NaN         NaN         NaN
# OG_PI_7_Tage_R_Wert            NaN         NaN         NaN         NaN
#
# Datum                   2020-03-06  2020-03-07  2020-03-08  2020-03-09  \
# PS_COVID_Faelle             757.00      984.00     1336.00     2021.00
# UG_PI_COVID_Faelle          732.00      958.00     1308.00     1985.00
# OG_PI_COVID_Faelle          783.00     1010.00     1370.00     2052.00
# PS_COVID_Faelle_ma4         507.00      673.00      895.00     1274.00
# UG_PI_COVID_Faelle_ma4      488.00      651.00      870.00     1245.00
# OG_PI_COVID_Faelle_ma4      528.00      696.00      922.00     1304.00
# PS_7_Tage_R_Wert              2.34        2.56        2.93        3.13
# UG_PI_7_Tage_R_Wert           2.28        2.51        2.88        3.08
# OG_PI_7_Tage_R_Wert           2.39        2.61        2.98        3.18
#
# Datum                   2020-03-10  2020-03-11  ...  2020-09-08  2020-09-09  \
# PS_COVID_Faelle            2573.00     3237.00  ...     1583.00     1599.00
# UG_PI_COVID_Faelle         2529.00     3190.00  ...     1541.00     1552.00
# OG_PI_COVID_Faelle         2623.00     3283.00  ...     1626.00     1655.00
# PS_COVID_Faelle_ma4        1728.00     2292.00  ...     1408.00     1519.00
# UG_PI_COVID_Faelle_ma4     1695.00     2253.00  ...     1365.00     1474.00
# OG_PI_COVID_Faelle_ma4     1764.00     2332.00  ...     1454.00     1570.00
# PS_7_Tage_R_Wert              3.22        3.12  ...        1.10        1.11
# UG_PI_7_Tage_R_Wert           3.18        3.08  ...        1.08        1.09
# OG_PI_7_Tage_R_Wert           3.26        3.16  ...        1.11        1.12
#
# Datum                   2020-09-10  2020-09-11  2020-09-12  2020-09-13  \
# PS_COVID_Faelle            1627.00     1642.00     1536.00     1576.00
# UG_PI_COVID_Faelle         1577.00     1594.00     1497.00     1532.00
# OG_PI_COVID_Faelle         1683.00     1701.00     1604.00     1629.00
# PS_COVID_Faelle_ma4        1600.00     1613.00     1601.00     1595.00
# UG_PI_COVID_Faelle_ma4     1553.00     1566.00     1555.00     1550.00
# OG_PI_COVID_Faelle_ma4     1652.00     1666.00     1660.00     1654.00
# PS_7_Tage_R_Wert              1.12        1.15        1.14        1.15
# UG_PI_7_Tage_R_Wert           1.10        1.13        1.13        1.14
# OG_PI_7_Tage_R_Wert           1.13        1.16        1.16        1.17
#
# Datum                   2020-09-14  2020-09-15  2020-09-16  2020-09-17
# PS_COVID_Faelle            2124.00     1966.00     1887.00     1721.00
# UG_PI_COVID_Faelle         2070.00     1910.00     1844.00     1679.00
# OG_PI_COVID_Faelle         2176.00     2017.00     1942.00     1773.00
# PS_COVID_Faelle_ma4        1720.00     1801.00     1888.00     1924.00
# UG_PI_COVID_Faelle_ma4     1673.00     1752.00     1839.00     1876.00
# OG_PI_COVID_Faelle_ma4     1777.00     1856.00     1941.00     1977.00
# PS_7_Tage_R_Wert              1.15        1.14        1.12        1.07
# UG_PI_7_Tage_R_Wert           1.14        1.12        1.10        1.06
# OG_PI_7_Tage_R_Wert           1.16        1.15        1.13        1.08
#
# [9 rows x 200 columns]

# %%
df2.plot()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <AxesSubplot:xlabel='Datum'>

# %%
len(df2_1)- 24
# Out:
# 693

# %%
test_size = 24

# %%
test_ind = len(df2_1)- test_size

# %%
test = df2_1.iloc[test_ind:]

# %%
X_test[1]
# Out:
# array([0.05838689])

# %%
test.plot(figsize=(12,10))
# Out:
# <img src="data:image/png;base64,..." width="1309">
# <AxesSubplot:xlabel='Datum'>

# %%
df2_1.mean()
# Out:
# PS_COVID_Faelle           18740.002789
# UG_PI_COVID_Faelle        18211.967922
# OG_PI_COVID_Faelle        19261.124128
# PS_COVID_Faelle_ma4       18368.283124
# UG_PI_COVID_Faelle_ma4    17945.687587
# OG_PI_COVID_Faelle_ma4    18794.358438
# dtype: float64

# %%
df2_1=df2_1.drop('PS_7_Tage_R_Wert',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-502-1694ba46114a> in <module>
# ----> 1 df2_1=df2_1.drop('PS_7_Tage_R_Wert',axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['PS_7_Tage_R_Wert'] not found in axis"

# %%
df2_1.plot()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <AxesSubplot:xlabel='Datum'>
